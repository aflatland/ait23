# %% [markdown]
# <a href="https://colab.research.google.com/github/24aef3/ait23/blob/main/assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://cdn.britannica.com/25/7125-050-67ACEC3C/Abyssinian-sorrel.jpg -O myimage.jpg
# Out:
# --2023-02-09 16:51:39--  https://cdn.britannica.com/25/7125-050-67ACEC3C/Abyssinian-sorrel.jpg
# Resolving cdn.britannica.com (cdn.britannica.com)... 65.8.11.41, 65.8.11.83, 65.8.11.116, ...
# Connecting to cdn.britannica.com (cdn.britannica.com)|65.8.11.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90626 (89K) [image/jpeg]
# Saving to: ‘myimage.jpg’
#
# myimage.jpg         100%[===================>]  88.50K  --.-KB/s    in 0.01s
#
# 2023-02-09 16:51:39 (8.31 MB/s) - ‘myimage.jpg’ saved [90626/90626]

# %%
from IPython.display import Image
img = Image('/content/myimage.jpg')
display(img)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/myimage.jpg')
image[0:30, 0:30, 0:30] = 0

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
